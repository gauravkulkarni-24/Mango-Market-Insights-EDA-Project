# %%
# ===============================================
# 📦 Import Libraries
# ===============================================
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# For clean visuals
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# ===============================================
# 🧾 Load the Mango Market Dataset
# ===============================================
df = pd.read_csv("Mango_Market_Insights.csv")

# Inspect columns
print(df.columns)
df.head()
# Out:
# Index(['State Name', 'District Name', 'Market Name', 'Variety', 'Group',
#        'Arrivals (Tonnes)', 'Min Price (Rs./Quintal)',
#        'Max Price (Rs./Quintal)', 'Modal Price (Rs./Quintal)', 'Reported Date',
#        'Grade', 'Month'],
#       dtype='object')
#     State Name District Name Market Name         Variety   Group  \
# 0  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 1  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 2  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 3  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 4  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
#
#    Arrivals (Tonnes)  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                0.1                  10000.0                  30000.0
# 1                0.2                  51000.0                  51000.0
# 2                0.6                  13000.0                  25000.0
# ...

# %%
# Handle numeric conversion if not already numeric
for col in ['Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)', 'Modal Price (Rs./Quintal)', 'Arrivals (Tonnes)']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df
# Out:
#        State Name District Name Market Name         Variety   Group  \
# 0     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 1     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 2     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 3     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 4     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# ...           ...           ...         ...             ...     ...
# 1793  Maharashtra      Sholapur     Solapur           Other  Fruits
# 1794  Maharashtra      Sholapur     Solapur           Other  Fruits
# 1795  Maharashtra      Sholapur     Solapur           Other  Fruits
# 1796  Maharashtra         Thane      Kalyan  Hapus(Alphaso)  Fruits
# 1797  Maharashtra         Thane      Kalyan        Totapuri  Fruits
#
#       Arrivals (Tonnes)  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                   0.1                  10000.0                  30000.0
# ...

# %%
# ===============================================
# 1️⃣ Monthly Price Trend Analysis                     ############################# Done!  3
# ===============================================
monthly_prices = df.groupby('Month')['Modal Price (Rs./Quintal)'].mean().reindex(
    ['January','February','March','April','May','June','July','August','September','October','November','December'])

#plt.figure(figsize=(6,4))
sns.lineplot(x=monthly_prices.index, y=monthly_prices.values, marker='o', linewidth=3, color="#2C7BB6")
plt.title("Monthly Average Modal Price of Mango (2025)", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Average Modal Price (Rs./Quintal)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# ===============================================
# 2️⃣ Supply vs Price Relationship
# ===============================================
plt.figure(figsize=(6,4))
sns.scatterplot(x='Arrivals (Tonnes)', y='Modal Price (Rs./Quintal)', data=df, color='orange', s=80, hue = 'Variety')
plt.title("Relationship between Supply and Mango Prices", fontsize=14)
plt.xlabel("Arrivals (Tonnes)")
plt.ylabel("Modal Price (Rs./Quintal)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %%
# ===============================================
# 2️⃣ Supply vs Price Relationship
# ===============================================
plt.figure(figsize=(6,4))
sns.scatterplot(x='Arrivals (Tonnes)', y='Modal Price (Rs./Quintal)', data=df, color='orange', s=80, hue = 'Variety')
plt.title("Relationship between Supply and Mango Prices", fontsize=14)
plt.xlabel("Arrivals (Tonnes)")
plt.ylabel("Modal Price (Rs./Quintal)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.xlim(0,200)
plt.ylim(0,20000)
plt.legend()
plt.show()
plt.save
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 14
#      12 plt.legend()
#      13 plt.show()
# ---> 14 plt.save
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'save'

# %%
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\580408758.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=market_avg.values, y=market_avg.index, palette="crest")

# %%
# ===============================================
# 4️⃣ Price Volatility Analysis (Max - Min)
# ===============================================
df['Price Spread'] = df['Max Price (Rs./Quintal)'] - df['Min Price (Rs./Quintal)']
volatility = df.groupby('Market Name')['Price Spread'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=volatility.values, y=volatility.index, palette="mako")
plt.title("Top 10 Markets by Price Volatility", fontsize=14)
plt.xlabel("Average Price Spread (Rs./Quintal)")
plt.ylabel("Market Name")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\2388044943.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=volatility.values, y=volatility.index, palette="mako")

# %%
# ===============================================
# 5️⃣ Monthly Arrivals Trend                      ###################### Done! 2
# ===============================================
monthly_arrivals = df.groupby('Month')['Arrivals (Tonnes)'].sum().reindex(
    ['January','February','March','April','May','June','July','August','September','October','November','December'])

plt.figure(figsize=(6,4))
sns.barplot(x=monthly_arrivals.index, y=monthly_arrivals.values, color="#FDAE61")
plt.title("Monthly Total Mango Arrivals in Maharashtra (2025)")
plt.xlabel("Month")
plt.ylabel("Total Arrivals (Tonnes)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 🟨 Slide 10: Top Performing Markets (Profit Zone)         ################## Done!  4

top_markets = df.groupby('Market Name')['Modal Price (Rs./Quintal)'].mean().sort_values(ascending=False).head(5)
sns.barplot(x=top_markets.index, y=top_markets.values, palette='viridis')
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\3574454808.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_markets.index, y=top_markets.values, palette='viridis')
# <Axes: xlabel='Market Name'>

# %%
top_markets = df.groupby('Market Name')['Modal Price (Rs./Quintal)'].mean().sort_values(ascending=False).head(5)

plt.figure(figsize=(7,5))
sns.barplot(x=top_markets.values, y=top_markets.index, palette='crest')

plt.title("Top 5 Markets by Average Modal Price", fontsize=16, weight='bold', color='darkblue')
plt.xlabel("Average Modal Price (Rs./Quintal)", fontsize=12)
plt.ylabel("Market Name", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\3722933257.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_markets.values, y=top_markets.index, palette='crest')

# %%
# 🟧 Slide 3: Minimum, Maximum & Modal Price Comparison

df[['Min Price (Rs./Quintal)','Modal Price (Rs./Quintal)','Max Price (Rs./Quintal)']].plot(kind='box')
plt.title("Mango Price Range Comparison")
# Out:
# Text(0.5, 1.0, 'Mango Price Range Comparison')

# %%
# 🟨 Slide 2: Overall Price Distribution (Univariate)             ######
sns.histplot(df['Modal Price (Rs./Quintal)'], kde=True, color='orange')
plt.title("Distribution of Mango Prices Across Maharashtra")
# Out:
# Text(0.5, 1.0, 'Distribution of Mango Prices Across Maharashtra')

# %%
# 🟨 Slide 4: Monthly Average Price Trend
monthly_avg = df.groupby('Month')['Modal Price (Rs./Quintal)'].mean()
sns.lineplot(x=monthly_avg.index, y=monthly_avg.values, marker='o', color='green')
# Out:
# <Axes: xlabel='Month'>

# %%
# 🟨 Slide 6: Supply vs Price Relationship (Bivariate)
sns.scatterplot(x='Arrivals (Tonnes)', y='Modal Price (Rs./Quintal)', data=df, color='purple')
sns.regplot(x='Arrivals (Tonnes)', y='Modal Price (Rs./Quintal)', data=df, scatter=False)
# Out:
# <Axes: xlabel='Arrivals (Tonnes)', ylabel='Modal Price (Rs./Quintal)'>

# %%
# 🟧 Slide 7: Market-Wise Price Comparison
market_avg = df.groupby('Market Name')['Modal Price (Rs./Quintal)'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=market_avg.values, y=market_avg.index, palette='YlOrBr')
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\3850381392.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=market_avg.values, y=market_avg.index, palette='YlOrBr')
# <Axes: ylabel='Market Name'>

# %%
df['Variety'].value_counts()
# Out:
# Variety
# Other             1208
# Hapus(Alphaso)     326
# Totapuri           264
# Name: count, dtype: int64

# %%
df
# Out:
#        State Name District Name Market Name         Variety   Group  \
# 0     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 1     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 2     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 3     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 4     Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# ...           ...           ...         ...             ...     ...
# 1793  Maharashtra      Sholapur     Solapur           Other  Fruits
# 1794  Maharashtra      Sholapur     Solapur           Other  Fruits
# 1795  Maharashtra      Sholapur     Solapur           Other  Fruits
# 1796  Maharashtra         Thane      Kalyan  Hapus(Alphaso)  Fruits
# 1797  Maharashtra         Thane      Kalyan        Totapuri  Fruits
#
#       Arrivals (Tonnes)  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                   0.1                  10000.0                  30000.0
# ...

# %%
# 🟨 Slide 8: Price Volatility (New Column)

df['Price Spread'] = df['Max Price (Rs./Quintal)'] - df['Min Price (Rs./Quintal)']
spread_avg = df.groupby('Market Name')['Price Spread'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=spread_avg.values, y=spread_avg.index, palette='coolwarm')
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\1744206681.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=spread_avg.values, y=spread_avg.index, palette='coolwarm')
# <Axes: ylabel='Market Name'>

# %%
#############       1

variety_data = df.groupby('Variety')['Arrivals (Tonnes)'].sum()
#plt.figure(figsize=(8,8))
sns.set(style = 'darkgrid')
plt.pie(variety_data, labels=variety_data.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'),explode = (0.01,0.01,0.01),shadow = True)
plt.title("Share of Each Mango Variety in Total Arrivals", fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group data by Variety
variety_data = df.groupby('Variety')['Arrivals (Tonnes)'].sum().sort_values(ascending=False)

# Define custom colors for a bright mango theme 🍋🥭
colors = sns.color_palette("flare", n_colors=len(variety_data))

# Plot the pie chart
#plt.figure(figsize=(9,8))
wedges, texts, autotexts = plt.pie(
    variety_data,
    labels=variety_data.index,
    autopct='%1.1f%%',
    startangle=120,
    colors=colors,
    textprops={'fontsize': 11, 'color': 'black'},
    wedgeprops={'edgecolor': 'white', 'linewidth': 2, 'antialiased': True},
    pctdistance=0.8
)

# Make percentage text bold and colorful
for autotext in autotexts:
    autotext.set_color("white")
    autotext.set_fontweight("bold")
    autotext.set_fontsize(11)

# Add title and styling
plt.title("🍋 Share of Each Mango Variety in Total Arrivals (Tonnes)", fontsize=15, fontweight='bold', color="#333333", pad=20)
plt.legend(variety_data.index, title="Variety", bbox_to_anchor=(1.05, 0.9), loc='upper left', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\4142147912.py:32: UserWarning: Glyph 127819 (\N{LEMON}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\GAURAV\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127819 (\N{LEMON}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.to_excel('Web_Scraping_Project.xlsx', index = False)
print('Done')
# Out:
# Done

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df['Arrivals (Tonnes)'], kde=True, bins=10, color='skyblue')      # box
plt.title('Distribution of Mango Arrivals (Tonnes)', fontsize=14, weight='bold')
plt.xlabel('Arrivals (Tonnes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/Mango_Analysis_Data.csv")

# %%
df.drop('State Name', axis=1, inplace=True)

# %%
df.drop('Group', axis=1, inplace=True)

# %%
df.drop('Grade', axis=1, inplace=True)

# %%
df.head()
# Out:
#   District Name Market Name         Variety  Arrivals (Tonnes)  \
# 0    Ahmednagar  Ahmednagar  Hapus(Alphaso)                0.1
# 1    Ahmednagar  Ahmednagar  Hapus(Alphaso)                0.2
# 2    Ahmednagar  Ahmednagar  Hapus(Alphaso)                0.6
# 3    Ahmednagar  Ahmednagar  Hapus(Alphaso)                0.8
# 4    Ahmednagar  Ahmednagar  Hapus(Alphaso)                1.1
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                    10000                    30000
# 1                    51000                    51000
# 2                    13000                    25000
# 3                    23000                    36000
# 4                    31000                    45000
#
#    Modal Price (Rs./Quintal) Reported Date  Month  Price Spread  Sales (Rs.)  \
# 0                      20000    2025-04-08  April         20000      20000.0
# 1                      51000    2025-03-18  March             0     102000.0
# ...

# %%
df.to_excel('Web_Scraping_Project1.xlsx', index = False)
print('Done')
# Out:
# Done

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Sales (Tonnes)'], kde=True, bins=10, color='orange')    #box
plt.title('Distribution of Mango Sales (Tonnes)', fontsize=14, weight='bold')
plt.xlabel('Sales (Tonnes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
########     1


plt.figure(figsize=(8,6))
sns.scatterplot(x='Arrivals (Tonnes)', y='Sales (Tonnes)', data=df, color='blue', s=80)
plt.title('Relationship between Arrivals and Sales', fontsize=14, weight='bold')
plt.xlabel('Arrivals (Tonnes)', fontsize=12)
plt.ylabel('Sales (Tonnes)', fontsize=12)
plt.show()

# %%
##########        Done!
 

month_group = df.groupby("Month")[["Arrivals (Tonnes)", "Sales (Tonnes)"]].sum().reset_index()

plt.figure(figsize=(6,4))
plt.plot(month_group["Month"], month_group["Arrivals (Tonnes)"], marker='o', label="Arrivals (Tonnes)", color='skyblue')
plt.plot(month_group["Month"], month_group["Sales (Tonnes)"], marker='o', label="Sales (Tonnes)", color='orange')

plt.title("Month-wise Mango Arrivals and Sales Trend", fontsize=14, weight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Tonnes", fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Monthly Trend of Average Selling Price
plt.figure(figsize=(8,5))
sns.barplot(x='Month', y='Selling Price (Rs./Quintal)', data=df, estimator='mean', palette='coolwarm')
plt.title('Average Selling Price by Month', fontsize=14, weight='bold')
plt.xlabel('Month')
plt.ylabel('Avg Selling Price (Rs./Quintal)')
plt.show()
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\3822836030.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Month', y='Selling Price (Rs./Quintal)', data=df, estimator='mean', palette='coolwarm')

# %%
import numpy as np

# %%
#✅ Step 1: If not already loaded, load your dataset             ################    1
df = pd.read_excel("Web_Scraping_Project.xlsx", sheet_name="Sheet1")

#✅ Step 2: Create a realistic 'Sales (Tonnes)' column (if not present)
df["Sales (Tonnes)"] = df["Arrivals (Tonnes)"] * np.random.uniform(0.7, 0.95, len(df))
df["Sales (Tonnes)"] = df["Sales (Tonnes)"].round(2)

#✅ Step 3: Group data by 'Variety'
variety_group = df.groupby("Variety")[["Arrivals (Tonnes)", "Sales (Tonnes)"]].sum().reset_index()

#✅ Step 4: Plotting
x = np.arange(len(variety_group["Variety"]))  # label locations
width = 0.35  # width of the bars

fig, ax = plt.subplots(figsize=(6,4))
bars1 = ax.bar(x - width/2, variety_group["Arrivals (Tonnes)"], width, label='Arrivals (Tonnes)', color='skyblue')
bars2 = ax.bar(x + width/2, variety_group["Sales (Tonnes)"], width, label='Sales (Tonnes)', color='orange')

#✅ Step 5: Formatting the chart
ax.set_xlabel("Mango Variety", fontsize=12, weight='bold')
ax.set_ylabel("Quantity (Tonnes)", fontsize=12, weight='bold')
ax.set_title("Variety-wise Mango Arrivals and Sales (in Tonnes)", fontsize=14, weight='bold')
ax.set_xticks(x)
ax.set_xticklabels(variety_group["Variety"], ha="right")
ax.legend()

plt.tight_layout()
plt.show()

plt.savefig('Variety-wise Mango Arrivals and Sales (in Tonnes)')

# %%
df.head()
# Out:
#     State Name District Name Market Name         Variety   Group  \
# 0  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 1  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 2  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 3  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
# 4  Maharashtra    Ahmednagar  Ahmednagar  Hapus(Alphaso)  Fruits
#
#    Arrivals (Tonnes)  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                0.1                    10000                    30000
# 1                0.2                    51000                    51000
# 2                0.6                    13000                    25000
# 3                0.8                    23000                    36000
# 4                1.1                    31000                    45000
#
#    Modal Price (Rs./Quintal) Reported Date  Grade  Month  Price Spread  \
# 0                      20000    2025-04-08  Local  April         20000
# ...

# %%
#1️⃣ Profit & Loss Analysis (Most Powerful Next Step)

#👉 Why: Helps identify which mango varieties or months gave the highest earnings.
#💡 What to do:
#Create a Profit (Rs.) column based on Selling Price and Modal Price.

#💰 Profit = (Selling Price - Modal Price) * Sales (Tonnes) * 10
df["Profit (Rs.)"] = (df["Selling Price (Rs./Quintal)"] - df["Modal Price (Rs./Quintal)"]) * df["Sales (Tonnes)"] * 10

#Variety-wise Profit
profit_variety = df.groupby("Variety")["Profit (Rs.)"].sum().reset_index()

#Plot
plt.figure(figsize=(10,6))
sns.barplot(x="Variety", y="Profit (Rs.)", data=profit_variety, palette="crest")
plt.title("Variety-wise Total Profit from Mango Sales", fontsize=14, weight='bold')
plt.xticks(rotation=45)
plt.ylabel("Profit (Rs.)")
plt.tight_layout()
plt.show()


#🎙️ In presentation:

#“Here we see which mango varieties are most profitable.
#Even if some varieties have high sales, profit depends on the selling price margin.
#This graph clearly shows which type yields maximum returns to farmers.”
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_820\928007786.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Variety", y="Profit (Rs.)", data=profit_variety, palette="crest")

# %%
district_sales = df.groupby("District Name")[["Arrivals (Tonnes)", "Sales (Tonnes)"]].sum().reset_index()

plt.figure(figsize=(10,6))
sns.barplot(x="District Name", y="Sales (Tonnes)", data=district_sales, color='orange')
plt.title("District-wise Mango Sales (Tonnes)", fontsize=14, weight='bold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
